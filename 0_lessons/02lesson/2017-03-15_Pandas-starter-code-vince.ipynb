# %% [markdown]
# pandas cheat sheet: https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf
#
# pandas data structures: http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro
#
# clone repo: https://github.com/rudeboybert/JSE_OkCupid

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Question 1: Print files in current working directory using command line tools.
# With Jupyter notebooks, you have access to your kernel if you preface your command with an exclamation point. Using command line, print out all files in your current working directory.

# %%
# !ls
# Out:
# 2017-03-15_Pandas-starter-code-vince.ipynb
# 2017-03-15_Pandas-starter-code.ipynb
# 2017-03-15_Pandas.ipynb

# %% [markdown]
# ## Question 2: Print out the path to your current working directory.

# %%
# !pwd
# Out:
# /Users/revit/general_assembly_git/DS-SF-33/lessons/02/notebooks

# %% [markdown]
# ## Question 3: Print out files in the data folder. The data folder lives in the same directory as the lessons folder. Use "../" to list files in the data folder.

# %%
# !ls ../data
# Out:
# dataset-02-ozone.csv okcupid_codebook.txt

# %% [markdown]
# ## Question 4: Read documentation for panda's pd.read_csv() command using the command pd.read_csv?

# %%
import pandas
pandas.read_csv?

# %% [markdown]
# ## Question 5: Read the csv file into a DataFrame, using panda's pd.read_csv() command.

# %%
okdata = pandas.read_csv('../data/profiles.csv')
# okdata.head()

# %% [markdown]
# ## Question 6: Print out the top 5 rows of the DataFrame, using df.head() command.

# %%
okdata.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# 4  creating imagery to look at:<br />\nhttp://bag...
#
#                                               essay3    ...      \
# 0  the way i look. i am a six foot half asian, ha...    ...
# 1                                                NaN    ...
# 2  my large jaw and large glasses are the physica...    ...
# 3                  socially awkward but i do my best    ...
# 4            i smile a lot and my inquisitive nature    ...
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Question 7: How many rows are in the data frame?

# %%
okdata.shape
# There are 59946 rows in the dataframe
# Out:
# (59946, 31)

# %% [markdown]
# ## Question 8: What are the names of the rows?

# %%
# each row is a profile observation, but the rows aren't labelled with anything more than a number
okdata.index.names
print('row names: ',okdata.index.get_values())
# Out:
# row names:  [    0     1     2 ..., 59943 59944 59945]

# %% [markdown]
# ## Question 9: What type of index is the row index?

# %%
okdata.index
# The rows index for this data is a general range index.
# Out:
# RangeIndex(start=0, stop=59946, step=1)

# %% [markdown]
# ## Question 10: Print out the column/feature names.

# %%
okdata.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %% [markdown]
# ## Question 11: Print out the data types of the columns (using attribute dtypes).

# %%
#okdata.columns.tolist()
#okdata['age'].dtype
col_list = okdata.columns.tolist()
for cname in col_list:
    if len(cname) < 8:
        print (cname,'\t\t', okdata[cname].dtype)
    else:
        print (cname,'\t', okdata[cname].dtype)
# Out:
# age 		 int64
# body_type 	 object
# diet 		 object
# drinks 		 object
# drugs 		 object
# education 	 object
# essay0 		 object
# essay1 		 object
# essay2 		 object
# essay3 		 object
# essay4 		 object
# essay5 		 object
# essay6 		 object
# essay7 		 object
# essay8 		 object
# essay9 		 object
# ethnicity 	 object
# height 		 float64
# income 		 int64
# job 		 object
# last_online 	 object
# location 	 object
# offspring 	 object
# orientation 	 object
# pets 		 object
# religion 	 object
# sex 		 object
# sign 		 object
# smokes 		 object
# speaks 		 object
# status 		 object

# %% [markdown]
# ## Question 12: Print out the last 3 rows of df, using .tail() command. Read documentation to specify number of rows to view.

# %%
okdata.tail(3)
# Out:
#        age body_type             diet      drinks  drugs  \
# 59943   42   average  mostly anything  not at all  never
# 59944   27  athletic  mostly anything    socially  often
# 59945   39   average              NaN    socially    NaN
#
#                             education  \
# 59943  graduated from masters program
# 59944   working on college/university
# 59945  graduated from masters program
#
#                                                   essay0  \
# 59943  hello! i enjoy traveling, watching movies, and...
# 59944  "all i have in this world are my balls and my ...
# 59945  is it odd that having a little "enemy" status ...
#
#                                                   essay1  \
# 59943  i'm a civil engineer, who enjoys helping the c...
# 59944  following my dreams...<br />\n"you got a dream...
# 59945  i work with elderly people (psychotherapy and ...
#
#                                                   essay2  \
# 59943  - looking at things objectively<br />\n- getti...
# 59944                                          listening
# 59945  i'm a great bullshitter. i don't know what it ...
#
#                                                   essay3   ...    \
# 59943  i'm quiet until i get used to the environment ...   ...
# 59944  it used to be the hair until i mowed it off bu...   ...
# 59945  either that i am funny/sarcastic, or that i am...   ...
#
#                               location  \
# 59943  south san francisco, california
# 59944        san francisco, california
# 59945        san francisco, california
#
#                                      offspring orientation  \
# 59943                  doesn&rsquo;t have kids    straight
# 59944  doesn&rsquo;t have kids, but wants them    straight
# 59945                                      NaN         gay
#
#                             pets                                   religion  \
# 59943                        NaN  christianity but not too serious about it
# 59944  likes dogs and likes cats   agnosticism but not too serious about it
# 59945  likes dogs and likes cats          catholicism and laughing about it
#
#       sex                                      sign          smokes  \
# 59943   m   sagittarius but it doesn&rsquo;t matter              no
# 59944   m     leo and it&rsquo;s fun to think about  trying to quit
# 59945   m  gemini and it&rsquo;s fun to think about       sometimes
#
#                                                   speaks  status
# 59943                                 english (fluently)  single
# 59944  english (fluently), spanish (poorly), chinese ...  single
# 59945                                            english  single
#
# [3 rows x 31 columns]

# %% [markdown]
# # Question 13: Using describe command, view a quick summary of the numeric data within the data frame.

# %%
okdata.describe()
# describe only shows these three columsn since they are int, float and int.
# the other columns are of type object and can't be summarized numerically, in this way.
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %% [markdown]
# ## Question 15: Put the result of the describe command into a variable, df2. What type is df2?

# %%
df2 = okdata.describe()
type(df2)
# d2 is a DataFrame.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Quesiton 16: What are the row names and column names of df2?

# %%
print ("Column Names:\t",df2.columns.get_values())
print ("Row Names:\t",df2.index.get_values())
# Out:
# Column Names:	 ['age' 'height' 'income']
# Row Names:	 ['count' 'mean' 'std' 'min' '25%' '50%' '75%' 'max']

# %% [markdown]
# ## Question 17: Generate a random number with a value between 0 and the number of rows in df. Set seed to 42 using `np.random.RandomState(42)`. Set the value of the random number equal to the variable pick. Check your neighbor's value.

# %%
len(okdata)
#np.random.rand()
np.random.RandomState(42)
    # above. initialized the random number generator with a value of 42
    # then we generate a radnom number.
pick = np.random.randint(len(okdata))
    # randint will use 0 as the low when no specified
    # also randint is EXclusive of the high end, whereas random_integers is inclusive.
print (pick)
# Out:
# 12032

# %% [markdown]
# ## Question 18: What is its data type of the age column of df?

# %%
type(okdata['age'])
# The age columns is considered a Series.
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Question 19: Using the iloc attribute, choose the row of df present at the value of `pick`.

# %%
"""pick was our randomly generated variable form above.
It's within the randof the length of the dataframe. We select that row with iloc,
and get that observation."""
okdata.iloc[pick]
# Out:
# age                                                           27
# body_type                                                average
# diet                                             mostly anything
# drinks                                                  socially
# drugs                                                      never
# education                      graduated from college/university
# essay0         i'm a down to earth guy who enjoys going on ad...
# essay1         currently working at a retail store with a ba ...
# essay2         listening to people, enjoy conversations, enjo...
# essay3                                  i like to talk to people
# essay4         shows: the office, breaking bad, simpson, dead...
# essay5                 friends, sleep, food, movies, anime, life
# essay6                                                       NaN
# essay7         hanging out with friends @ a bar or watching a...
# essay8                                                       NaN
# essay9                                 your interested in dating
# ethnicity                                                  asian
# height                                                        66
# income                                                        -1
# job                                  sales / marketing / biz dev
# last_online                                     2012-03-24-21-14
# location                               san francisco, california
# offspring                                                    NaN
# orientation                                             straight
# pets                                     has dogs and likes cats
# religion                                                     NaN
# sex                                                            m
# sign                                                         NaN
# smokes                                                        no
# speaks                                        english (fluently)
# status                                                    single
# Name: 12032, dtype: object

# %% [markdown]
# ## Question 20: Select the first three rows of df:

# %%
okdata.head(3)
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
#
#                         education  \
# 0   working on college/university
# 1           working on space camp
# 2  graduated from masters program
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3    ...      \
# 0  the way i look. i am a six foot half asian, ha...    ...
# 1                                                NaN    ...
# 2  my large jaw and large glasses are the physica...    ...
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
#
# [3 rows x 31 columns]

# %% [markdown]
# ## Question 21. using loc command, select the `drinks` column.

# %%
okdata.loc[:,['drinks']]
# you have to ask for ALL rows, but only column "drinks". Row selection is before the comma
# Out:
#            drinks
# 0        socially
# 1           often
# 2        socially
# 3        socially
# 4        socially
# 5        socially
# 6        socially
# 7        socially
# 8        socially
# 9      not at all
# 10       socially
# 11       socially
# 12          often
# 13       socially
# 14       socially
# 15       socially
# 16       socially
# 17       socially
# 18         rarely
# 19       socially
# 20       socially
# 21       socially
# 22       socially
# 23     not at all
# 24       socially
# 25         rarely
# 26       socially
# 27       socially
# 28       socially
# 29       socially
# ...           ...
# 59916    socially
# 59917    socially
# 59918    socially
# 59919         NaN
# 59920    socially
# 59921    socially
# 59922    socially
# 59923    socially
# 59924    socially
# 59925    socially
# 59926    socially
# 59927    socially
# 59928    socially
# 59929    socially
# 59930    socially
# 59931      rarely
# 59932    socially
# 59933    socially
# 59934    socially
# 59935    socially
# 59936    socially
# 59937    socially
# 59938         NaN
# 59939    socially
# 59940    socially
# 59941    socially
# 59942       often
# 59943  not at all
# 59944    socially
# 59945    socially
#
# [59946 rows x 1 columns]

# %% [markdown]
# ## Question 22: Using iloc, select every other row starting from the first, and the 10th and 22nd column

# %%
okdata.iloc[okdata.index % 2 ==0, [9,21]]
# Out:
#                                                   essay3  \
# 0      the way i look. i am a six foot half asian, ha...
# 2      my large jaw and large glasses are the physica...
# 4                i smile a lot and my inquisitive nature
# 6                                  i am the last unicorn
# 8      i'm freakishly blonde and have the same name a...
# 10                                   my huge goofy smile
# 12                                                   NaN
# 14     well, i get the most compliments on my butt, s...
# 16     lately, i keep getting asked "are you with the...
# 18     blue eyes and a kind soul... although i don't ...
# 20                                                   NaN
# 22           that i'm smiling. pretty much at all times.
# 24                                                   NaN
# 26          is how hard it is to pin point my ethnicity.
# 28     depends. i've been told my eyes (isn't this th...
# 30                                                   NaN
# 32                                  i'm guessing my hair
